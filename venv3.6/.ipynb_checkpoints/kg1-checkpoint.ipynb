# %%
import csv
import networkx as nx
import os
import pandas as pd
import math

# %%
G = nx.Graph()

# %%
edg = dict()

# %%
class node:
    def __init__(self):
        self.pos = []
        self.sen = []
        self.l = 0

# %%
data_path = '/home/nayan/coding/Major/sCake Phrase/venv/wordList'

# %%
for every_file in (os.listdir(data_path)):
    if every_file == 'combined.csv':
        continue
    rdr = csv.reader(open(data_path + '/' + every_file, 'r'))
    df = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/'+every_file[:-4] + '_ranked_list.csv', 'r'))
    key = list(df['Words'][:50])
    nodes = dict() 
    
    for i in range(50):
        if not G.has_node(key[i]):
            G.add_node(key[i])
        nodes[key[i]] = node()
        if key[i] not in edg:
            edg[key[i]] = dict()
        
    p = 0
    s = 0

    for line in rdr:
        for i in line:
            if i in key:
                nodes[i].pos.append(p)
                p += 1
                nodes[i].sen.append(s)
        s += 1
    for i in nodes:
        nodes[i].l = len(nodes[i].pos)
    
    for i in key:
        for j in key:
            
            if i == j:
                continue
            
            wt = 0
            
            for a in range(nodes[i].l):
                for b in range(nodes[j].l):
                    wt += ((nodes[i].pos[a] - nodes[j].pos[b])**2) * ((nodes[i].sen[a] - nodes[j].sen[b] + 1)**2)
            #print(i,j,wt)
            
            if G.has_edge(i, j):
                G[i][j]['weight'] += wt/2
            else:
                G.add_edge(i, j, weight = wt/2)
                
            if j in edg[i]:
                edg[i][j] += (nodes[i].l*nodes[j].l)
            else:
                edg[i][j] = (nodes[i].l*nodes[j].l)
                
            if wt == 0:
                G.remove_edge(i,j)
                del edg[i][j]
                #del edg[j][i]
                
            if i == 'franoi' and j == 'represent-text':
                print(G.has_edge('franoi','represent-text'))
# Out:
# False

# %%
for (u, v, d) in G.edges().data():
    if u == 'represent-text':
        print('v',v)
    if v == 'represent-text':
        print('u',u)
    G[u][v]['weight'] /= edg[u][v]
    G[u][v]['weight'] = math.sqrt(G[u][v]['weight'])
# Out:
# u text
# u abstract
# u method
# u appli
# u graph
# u extract
# u result
# u keyword
# u base
# u number
# u paper
# u document
# u compar
# u section
# u exist
# u approach
# u term
# u work
# u dataset
# u process
# u node
# u present
# u show
# u graphofword
# u singledocu-keyword-extract
# u vazirgianni
# u franoi
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a14579d329ea> in <module>
#       4     if v == 'represent-text':
#       5         print('u',u)
# ----> 6     G[u][v]['weight'] /= edg[u][v]
#       7     G[u][v]['weight'] = math.sqrt(G[u][v]['weight'])
#
# KeyError: 'represent-text'

# %%
print(sorted(G.edges(data=True), key=lambda t: t[2].get('weight', 1)))
# Out:
# [('text', 'applic-volum-januari', {'weight': 0.0}), ('order', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('abstract', 'applic-volum-januari', {'weight': 0.0}), ('abstract', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('model', 'applic-volum-januari', {'weight': 0.0}), ('model', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('method', 'applic-volum-januari', {'weight': 0.0}), ('method', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('scienc', 'applic-volum-januari', {'weight': 0.0}), ('inform', 'applic-volum-januari', {'weight': 0.0}), ('import', 'applic-volum-januari', {'weight': 0.0}), ('result', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('keyword', 'applic-volum-januari', {'weight': 0.0}), ('word', 'applic-volum-januari', {'weight': 0.0}), ('word', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('base', 'applic-volum-januari', {'weight': 0.0}), ('base', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('analysi', 'applic-volum-januari', {'weight': 0.0}), ('analysi', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('number', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('paper', 'applic-volum-januari', {'weight': 0.0}), ('document', 'applic-volum-januari', {'weight': 0.0}), ('document', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('data', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('repres', 'applic-volum-januari', {'weight': 0.0}), ('repres', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('identifi', 'applic-volum-januari', {'weight': 0.0}), ('approach', 'applic-volum-januari', {'weight': 0.0}), ('approach', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('index', 'applic-volum-januari', {'weight': 0.0}), ('term', 'applic-volum-januari', {'weight': 0.0}), ('term', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('techniqu', 'applic-volum-januari', {'weight': 0.0}), ('gener', 'applic-volum-januari', {'weight': 0.0}), ('gener', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('corpu', 'applic-volum-januari', {'weight': 0.0}), ('corpu', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('relat', 'applic-volum-januari', {'weight': 0.0}), ('evalu', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('phrase', 'applic-volum-januari', {'weight': 0.0}), ('topic', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('keyphras', 'applic-volum-januari', {'weight': 0.0}), ('dataset', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('textual', 'bioinformat-suppl-httpwwwbiomedcentralcomss', {'weight': 0.0}), ('languag', 'applic-volum-januari', {'weight': 0.0}), ('process', 'applic-volum-januari', {'weight': 0.0}), ('present', 'applic-volum-januari', {'weight': 0.0}), ('review', 'applic-volum-januari', {'weight': 0.0}), ('applic-volum-januari', 'keyword-keyphras-extract', {'weight': 0.0}), ('applic-volum-januari', 'content', {'weight': 0.0}), ('applic-volum-januari', 'featur', {'weight': 0.0}), ('applic-volum-januari', 'literatur', {'weight': 0.0}), ('applic-volum-januari', 'specif', {'weight': 0.0}), ('applic-volum-januari', 'survey', {'weight': 0.0}), ('applic-volum-januari', 'sifatullah', {'weight': 0.0}), ('applic-volum-januari', 'measur', {'weight': 0.0}), ('applic-volum-januari', 'find', {'weight': 0.0}), ('applic-volum-januari', 'siddiqi', {'weight': 0.0}), ('applic-volum-januari', 'interest', {'weight': 0.0}), ('applic-volum-januari', 'quickli', {'weight': 0.0}), ('applic-volum-januari', 'text-mine', {'weight': 0.0}), ('applic-volum-januari', 'reader', {'weight': 0.0}), ('applic-volum-januari', 'discuss', {'weight': 0.0}), ('applic-volum-januari', 'internet', {'weight': 0.0}), ('applic-volum-januari', 'field', {'weight': 0.0}), ('applic-volum-januari', 'select', {'weight': 0.0}), ('applic-v ...

# %%
if G.has_edge('franoi','represent-text'):
    print('vd')
# Out:
# vd
