# %%
from glove import Corpus, Glove
import csv

corpus = Corpus()

# %%
data_path = '/home/nayan/coding/Major/sCake Phrase/venv/wordList'

# %%
every_file = '52795.csv'

# %%
#for every_file in (os.listdir(data_path)):
lines = list(csv.reader(open(data_path + '/' + every_file, 'r')))

corpus.fit(lines, window=10)
glove = Glove(no_components=5, learning_rate=0.05)

glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
# Out:
# Performing 30 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
import pandas as pd

# %%
df = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/52795_ranked_list.csv', 'r'))

# %%
df.head()
# Out:
#    Unnamed: 0    Old_WScore  Position_Weight       SCScore  \
# 0         125  16115.859213         1.269917  20465.800371
# 1           1  36731.952174         0.368516  13536.311087
# 2         225  12690.234783         0.734886   9325.879466
# 3           4  33020.676812         0.163738   5406.743639
# 4          19  25572.913043         0.140756   3599.532809
#
#                  Words
# 0  bound-set-intersect
# 1            distribut
# 2           union-size
# 3                 data
# 4               method

# %%
for w in df['Words'][:10]:
    print (glove.word_vectors[glove.dictionary[w]])
# Out:
# [-0.06047356 -0.07402789  0.01828268 -0.01247974 -0.06479196]
# [-0.01719142 -0.09144776 -0.16825247 -0.06574383  0.00694816]
# [0.08149663 0.0279749  0.00077802 0.06408682 0.01590198]
# [ 0.07774163  0.00489846 -0.1361025  -0.05992462 -0.01461617]
# [-0.00796975 -0.03352185 -0.05218493  0.01774305 -0.06725631]
# [ 0.13590032  0.08201979  0.13745978  0.02971458 -0.003852  ]
# [ 1.79063183e-02 -7.68603289e-03 -3.97093118e-02  4.03831609e-02
#   5.08133146e-05]
# [-0.06685728 -0.0089203   0.04631221 -0.12214958  0.0272624 ]
# [ 0.10475579 -0.03710738  0.01120073  0.02765303  0.05013485]
# [ 8.17738751e-02 -8.77060031e-02 -4.04537124e-02 -7.61551025e-05
#   8.65462832e-02]

# %%
key = list(df['Words'])

# %%
print(glove.word_vectors[glove.dictionary['frequenc-upper-bound']])
# Out:
# ['bound-set-intersect', 'distribut', 'union-size', 'data', 'method', 'bound', 'statist', 'requir', 'rule', 'present']

# %%
import numpy as np

# %%
for i in key:
    for j in key:
        print(i)
        print(j)
        print(np.linalg.norm(glove.word_vectors[glove.dictionary[i]] - glove.word_vectors[glove.dictionary[j]]))
# Out:
# bound-set-intersect
# bound-set-intersect
# 0.0
# bound-set-intersect
# distribut
# 0.2120279874044975
# bound-set-intersect
# union-size
# 0.20794342304634741
# bound-set-intersect
# data
# 0.2322417252352704
# bound-set-intersect
# method
# 0.10140298134362155
# bound-set-intersect
# bound
# 0.2874209435188711
# bound-set-intersect
# statist
# 0.14459180558125023
# bound-set-intersect
# requir
# 0.15989647770038154
# bound-set-intersect
# rule
# 0.20864521501960914
# bound-set-intersect
# present
# 0.21662987240925985
# bound-set-intersect
# express
# 0.09523302588884476
# bound-set-intersect
# estim
# 0.26187862346508584
# bound-set-intersect
# databas
# 0.10387460080119662
# bound-set-intersect
# exploit
# 0.13553746367463704
# bound-set-intersect
# attribut
# 0.1851490613908247
# bound-set-intersect
# varieti
# 0.18176341717377315
# bound-set-intersect
# analysi
# 0.1397523336342442
# bound-set-intersect
# section
# 0.1788280932486978
# bound-set-intersect
# intersect
# ...
