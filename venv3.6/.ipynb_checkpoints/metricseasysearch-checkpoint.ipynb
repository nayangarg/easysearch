# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
from read_write_create import *
import csv
import pandas as pd
import os
import re
from nltk.util import ngrams

cwd=os.getcwd()
path=cwd
phrase_data= "/home/nayan/coding/Major/EasySearch/venv/SCScore_W"
gold_data= "/home/nayan/coding/Major/EasySearch/venv/keys"

ps = PorterStemmer()

# %%
def generate_ngrams(s, n, sep):
    
    tokens = [token for token in s.split(sep) if token != ""]
    
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def glist(fil):
    gold_list=[]
    #keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(gold_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for row in reader:
        for word in row:
            word=word.replace("-"," ")            
            gold_list.append(" ".join([ps.stem(i) for i in word.split()]))

    #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split(" ")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i," "))

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    print(gold)

    return gold
    
#print(gold)

# %%
def extList(fil, k):
    #gold_list=[]
    keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(phrase_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for i in range(1,len(reader)):
        if(int(reader[i][0])<=len(reader[:k])):
            keyword_list.append(reader[i][4])

    #print(gold_list)
    gold=[]
    for word in keyword_list:
        tokens=word.split("-")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i,'-'))
            
    #print(gold)

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    print(gold)

    return gold
    
#print(gold)

# %%
g = []
for i in gold:
    for j in i:
        g.append(j)
        

print(g)
# Out:
# ['databas', 'theori', 'databas theori', 'file', 'organis', 'file organis', 'boolean', 'algebra', 'boolean algebra', 'close', 'form', 'bound', 'close form', 'form bound', 'close form bound', 'databas', 'access', 'databas access', 'distribut', 'inform', 'distribut inform', 'rule', 'base', 'system', 'architectur', 'rule base', 'base system', 'system architectur', 'rule base system', 'base system architectur', 'rule base system architectur', 'set', 'intersect', 'set intersect', 'set', 'theori', 'set theori', 'statist', 'analysi', 'statist analysi', 'union', 'size', 'union size']

# %%
gold = []
for i in g:
#     for j in range(0,len(gold[i])):
    if ' ' in i:
        gold.append(i.replace(" ","-"))
        gold.append(i.replace(" ",""))
    else:
        gold.append(i)

print(gold)
# Out:
# ['databas', 'theori', 'databas-theori', 'databastheori', 'file', 'organis', 'file-organis', 'fileorganis', 'boolean', 'algebra', 'boolean-algebra', 'booleanalgebra', 'close', 'form', 'bound', 'close-form', 'closeform', 'form-bound', 'formbound', 'close-form-bound', 'closeformbound', 'databas', 'access', 'databas-access', 'databasaccess', 'distribut', 'inform', 'distribut-inform', 'distributinform', 'rule', 'base', 'system', 'architectur', 'rule-base', 'rulebase', 'base-system', 'basesystem', 'system-architectur', 'systemarchitectur', 'rule-base-system', 'rulebasesystem', 'base-system-architectur', 'basesystemarchitectur', 'rule-base-system-architectur', 'rulebasesystemarchitectur', 'set', 'intersect', 'set-intersect', 'setintersect', 'set', 'theori', 'set-theori', 'settheori', 'statist', 'analysi', 'statist-analysi', 'statistanalysi', 'union', 'size', 'union-size', 'unionsize']

# %%
for every_file in (os.listdir(phrase_data)):
    file_name = every_file[:-4]
    with open(cwd+"\\SCScore_W\\"+file_name+".csv", "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    for i in range(1,len(reader)):
        if(int(reader[i][0])<=len(reader)):
            keyword_list.append(reader[i][4]) 
print(keyword_list)
# Out:
# ['set-intersect-union', 'inform', 'bound-set-intersect', 'data', 'bound', 'method', 'union-size', 'catalog-quick-closedform', 'requir', 'statist', 'present', 'rule', 'express', 'estim', 'exploit', 'distribut', 'databas', 'analysi', 'absolut-bound', 'attribut', 'varieti', 'size', 'section', 'rulebas', 'stimat', 'homomorph', 'precomput', 'work', 'manag', 'tend', 'assum', 'system', 'simpl', 'architectur', 'easili', 'gener', 'level', 'subset', 'possibl', 'count', 'correl', 'intersect', 'involv', 'techniqu', 'handl', 'analyz', 'data-item-distribut', 'set-size', 'strong-complex-correl', 'standard', 'circumst', 'anytim', 'comput', 'situat', 'assumpt', 'item', 'difficult', 'valu', 'univers', 'frequenc', 'poorli', 'block', 'good', 'obtain', 'space', 'paper', 'mathemat', 'applic', 'estim-method', 'equival', 'page', 'reason', 'formula', 'size-set-intersect', 'number', 'time', 'independenceassumpt', 'need', 'frequencydistribut-bound', 'distributionalassumpt', 'numer', 'comput-estim', 'join', 'complement', 'relat', 'call', 'distribut-assumpt', 'minimum', 'arbitrari', 'suppos', 'includ', 'determin', 'base', 'union', 'import', 'studi', 'serv', 'algorithm', 'purpos', 'occur', 'rare', 'number-distinct-valu', 'prior', 'detail', 'make', 'evalu', 'sampl', 'rang', 'form', 'knowledg', 'precomput-inform-bound', 'result', 'appli', 'independ', 'defin', 'absolut', 'suffici', 'moment', 'perform', 'find', 'discuss', 'approach', 'infer', 'wkward', 'easier', 'verifi', 'user', 'upper-bound-size', 'primarili', 'optim', 'veragecas', 'strong', 'complic', 'model', 'deviat', 'bound-method', 'tighter', 'case', 'fill', 'kind', 'select', 'partit', 'multipl', 'altern', 'combin', 'setsiz', 'calcul', 'aris', 'previou-research', 'exist', 'studi-data', 'emphas', 'attri', 'ntersect', 'tabl', 'bute', 'common', 'xist', 'bound-tend', 'address', 'give', 'databas-access', 'permit', 'routin', 'ttribut', 'good-bound', 'repres', 'idea', 'explicitli', 'give-lower-bound', 'multivari-distribut', 'upper-bound-number', 'minima', 'term', 'probabilist', 'mode-frequenc-number', 'queri', 'extrema', 'bound-easier', 'mean', 'relev-work', 'support', 'incom', 'choic', 'group', 'import-bound', 'roblem', 'summari', 'principl', 'ound', 'overlap', 'random', 'set-intersect-defin', 'integr', 'upper-bound-intersect', 'level-upper-bound', 'problem', 'istribut', 'essenti', 'actual', 'diophantin-infer', 'equival-class', 'antisampl', 'weak', 'consid', 'approxima', 'tandard', 'note', 'figur', 'prove', 'independ-uniform-assumpt', 'prefer', 'design', 'natur-data', 'long', 'inequ', 'statist-databas', 'upper-bound-ntersect', 'recogn', 'issu', 'varianc', 'number-item', 'bound-set-union', 'quick', 'restrict', 'previou', 'scienc', 'divid', 'nalog', 'storag-requir', 'mode-common', 'worstcas', 'count-statist', 'character', 'languag', 'main', 'upper-bound-mode', 'set-defin-partit', 'total', 'compil', 'minimum-mode-frequenc', 'alloc', 'state', 'rangeanalysi', 'log-bit', 'prolog', 'analyt', 'mode', 'exploratori', 'summar', 'earli', 'retriev', 'year', 'nation', 'stage', 'size-databas', 'question', 'deriv', 'tatist', 'level-lower-bound', 'unlik', 'experi', 'minimumterm-form', 'attribut-valu', 'set-intersect-valu', 'maxima', 'respect', 'valuabl', 'section-examin', 'bound-intersect-size', 'execut', 'jth-attribut', 'complex', 'bound-provid', 'evel', 'least', 'categori', 'uppos', 'partit-attribut', 'frequenc-intersect', 'upperbound', 'investig', 'hyperrectangular-region', 'secur', 'store', 'averag', 'phenomena', 'indirect', 'hese', 'estim-size-intersect', 'extens', 'upper-bound-level', 'sameestim', 'cost', 'basi', 'entir', 'ystem', 'work-databas', 'pair', 'algebra', 'storag', 'iowan', 'bound-case', 'reced', 'improv', 'probabl-distribut', 'involv-bound', 'lower', 'uniqu', 'find-number', 'lie-age-rang', 'boolean-express', 'exampl', 'point', 'wast', 'call-level', 'nonzero-lower-bound', 'class-bound', 'mina', 'exact', 'elimin', 'prune', 'boolean', 'descript', 'paramet', 'maximum', 'ranchandbound', 'creat', 'approach-work', ' ...

# %%
tp=0;
fp=0;
fn=0;
fp=0;
g = glist('52795.key')
ext = extList('52795_ranked_list.csv')
for i in g:
    #print(i)
    if i in ext:
        print(i)
        tp=tp+1;
print(tp)
# Out:
# {'databas-theori', 'rule-base-system-architectur', 'architectur', 'set-intersect', 'distribut-inform', 'base-system-architectur', 'rule-base', 'fileorganis', 'settheori', 'rule-base-system', 'boolean', 'system', 'rulebasesystem', 'set', 'statist', 'intersect', 'size', 'systemarchitectur', 'form', 'access', 'union', 'databas-access', 'basesystem', 'analysi', 'unionsize', 'rule', 'set-theori', 'close-form', 'closeformbound', 'closeform', 'organis', 'form-bound', 'system-architectur', 'base-system', 'databasaccess', 'distribut', 'booleanalgebra', 'bound', 'base', 'basesystemarchitectur', 'databastheori', 'rulebasesystemarchitectur', 'statistanalysi', 'close', 'distributinform', 'rulebase', 'algebra', 'formbound', 'databas', 'inform', 'setintersect', 'close-form-bound', 'union-size', 'statist-analysi', 'boolean-algebra', 'file', 'theori', 'file-organis'}
# {'possibl', 'detail', 'size-set', 'calcul', 'log', 'union', 'call', 'level-upper-bound', 'data', 'tatist', 'experi', 'term', 'assum', 'bit', 'frequencydistributbound', 'levelupper', 'number-distinct-valu', 'logbit', 'equival', 'method', 'distribut', 'make', 'inform', 'minimum', 'formula', 'levellowerbound', 'level-lower-bound', 'set-size', 'prior', 'defin', 'numberdistinct', 'valu', 'techniqu', 'attribut', 'univers', 'upper', 'work', 'item', 'paper', 'distinctvalu', 'consid', 'combin', 'numberdistinctvalu', 'comput', 'import', 'suppos', 'space', 'includ', 'common', 'tend', 'level-upper', 'level-lower', 'complement', 'case', 'express', 'absolutbound', 'obtain', 'appli', 'setintersect', 'requir', 'occur', 'find', 'set', 'discuss', 'subset', 'intersect', 'emphas', 'applic', 'kind', 'upperbound', 'frequenc', 'count', 'form', 'gener', 'section', 'knowledg', 'determin', 'good', 'moment', 'lower-bound', 'number', 'absolut-bound', 'simpl', 'oundsize', 'time', 'levelupperbound', 'perform', 'bound', 'log-bit', 'levellower', 'situat', 'rang', 'databas', 'size-set-intersect', 'suffici', 'homomorph', 'give', 'ound-size', 'correl', 'relat', 'distinct-valu', 'approach', 'problem', 'exploit', 'set-intersect', 'aris', 'upper-bound', 'stimat', 'result', 'setsize', 'statist', 'size', 'number-distinct', 'instanc', 'frequencydistribut', 'absolut', 'analysi', 'tabl', 'rule', 'varieti', 'lowerbound', 'distinct', 'ound', 'optim', 'frequencydistribut-bound', 'estim', 'sizeset', 'studi', 'arbitrari', 'involv', 'level', 'storag', 'sizesetintersect', 'user', 'lower'}
# set-intersect
# set
# statist
# intersect
# size
# form
# union
# analysi
# rule
# distribut
# bound
# databas
# inform
# setintersect
# 14

# %%
a = extList('52795_ranked_list.csv')
# Out:
# {'requir', 'attribut', 'univers', 'set', 'setsize', 'intersect', 'size', 'frequenc', 'count', 'absolut', 'gener', 'data', 'assum', 'import', 'absolut-bound', 'method', 'distribut', 'complement', 'bound', 'inform', 'formula', 'correl', 'set-size', 'level', 'absolutbound', 'valu'}

# %%
len(glist('52795.key'))
# Out:
# {'databas-theori', 'rule-base-system-architectur', 'architectur', 'set-intersect', 'distribut-inform', 'base-system-architectur', 'rule-base', 'fileorganis', 'settheori', 'rule-base-system', 'boolean', 'system', 'rulebasesystem', 'set', 'statist', 'intersect', 'size', 'systemarchitectur', 'form', 'access', 'union', 'databas-access', 'basesystem', 'analysi', 'unionsize', 'rule', 'set-theori', 'close-form', 'closeformbound', 'closeform', 'organis', 'form-bound', 'system-architectur', 'base-system', 'databasaccess', 'distribut', 'booleanalgebra', 'bound', 'base', 'basesystemarchitectur', 'databastheori', 'rulebasesystemarchitectur', 'statistanalysi', 'close', 'distributinform', 'rulebase', 'algebra', 'formbound', 'databas', 'inform', 'setintersect', 'close-form-bound', 'union-size', 'statist-analysi', 'boolean-algebra', 'file', 'theori', 'file-organis'}
# 58
