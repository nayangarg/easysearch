# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
from read_write_create import *
import csv
import pandas as pd
import os
import re
from nltk.util import ngrams

cwd=os.getcwd()
path=cwd
phrase_data= "/home/nayan/coding/Major/sCAKE/venv/SCScore_W"
gold_data= "/home/nayan/coding/Major/EasySearch/venv/keys"
pred_data = "/home/nayan/coding/Major/EasySearch/venv/SCScore_W"

ps = PorterStemmer()

# %%
def generate_ngrams(s, n, sep):
    
    tokens = [token for token in s.split(sep) if token != ""]
    
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def glist(fil):
    gold_list=[]
    #keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(gold_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    l = len(reader)
    
    for row in reader:
        for word in row:
            word=word.replace("-"," ")            
            gold_list.append(" ".join([ps.stem(i) for i in word.split()]))

   #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split(" ")
        t = []
        for i in range(1,len(tokens)+1):
            ng = generate_ngrams(word,i," ")
            #print(ng)
            for j in ng:
                t.append(j)
        gold.append(t)
    #print(gold)
#     g = []
#     for i in gold:
#         for j in i:
#             g.append(j)
#     print(g)
    #gold = []
    res = []
    for i in gold:
        g = []
        for j in i:
            if ' ' in j:
                g.append(j.replace(" ","-"))
                g.append(j.replace(" ",""))
            else:
                g.append(j)
        res.append(g)
    #gold = set(gold)
            
    #print(res)

    return [res, l]
    
#print(gold)

# %%
len(glist('52795.key'))
# Out:
# [['databas', 'theori', 'databas theori'], ['file', 'organis', 'file organis'], ['boolean', 'algebra', 'boolean algebra'], ['close', 'form', 'bound', 'close form', 'form bound', 'close form bound'], ['databas', 'access', 'databas access'], ['distribut', 'inform', 'distribut inform'], ['rule', 'base', 'system', 'architectur', 'rule base', 'base system', 'system architectur', 'rule base system', 'base system architectur', 'rule base system architectur'], ['set', 'intersect', 'set intersect'], ['set', 'theori', 'set theori'], ['statist', 'analysi', 'statist analysi'], ['union', 'size', 'union size']]
# [['databas', 'theori', 'databas-theori', 'databastheori'], ['file', 'organis', 'file-organis', 'fileorganis'], ['boolean', 'algebra', 'boolean-algebra', 'booleanalgebra'], ['close', 'form', 'bound', 'close-form', 'closeform', 'form-bound', 'formbound', 'close-form-bound', 'closeformbound'], ['databas', 'access', 'databas-access', 'databasaccess'], ['distribut', 'inform', 'distribut-inform', 'distributinform'], ['rule', 'base', 'system', 'architectur', 'rule-base', 'rulebase', 'base-system', 'basesystem', 'system-architectur', 'systemarchitectur', 'rule-base-system', 'rulebasesystem', 'base-system-architectur', 'basesystemarchitectur', 'rule-base-system-architectur', 'rulebasesystemarchitectur'], ['set', 'intersect', 'set-intersect', 'setintersect'], ['set', 'theori', 'set-theori', 'settheori'], ['statist', 'analysi', 'statist-analysi', 'statistanalysi'], ['union', 'size', 'union-size', 'unionsize']]
# 2

# %%
def extList(fil, k):
    #gold_list=[]
    gold_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for i in range(1,k+1):
       # if(int(reader[i][0])<=len(reader[:k])):
        gold_list.append(reader[i][4])

    #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split("-")
        t = []
        for i in range(1,len(tokens)+1):
            ng = generate_ngrams(word,i,"-")
            #print(ng)
            for j in ng:
                t.append(j)
        gold.append(t)
#     print(gold)
#     g = []
#     for i in gold:
#         for j in i:
#             g.append(j)
#     print(g)
    #gold = []
    g = []
    for i in gold:
#         g = []
        for j in i:
            if ' ' in j:
                g.append(j.replace(" ","-"))
                g.append(j.replace(" ",""))
            else:
                g.append(j)
#         res.append(g)
#     g = set(g)
    #res = set(res)
    res = []  
    for i in g:
        res.append([i,0])
#     print(res)

    return [res, k]
    
#print(gold)

# %%
a = extList(pred_data+'/'+'629280_ranked_list.csv', 10)
print(a)
# Out:
# [['object', 0], ['system', 0], ['object-system', 0], ['objectsystem', 0], ['environ', 0], ['modular', 0], ['distribut', 0], ['modular-distribut', 0], ['modulardistribut', 0], ['structur', 0], ['system', 0], ['structur', 0], ['system-structur', 0], ['systemstructur', 0], ['found', 0], ['system', 0], ['propos', 0], ['design', 0], ['develop', 0], ['design-develop', 0], ['designdevelop', 0], ['implement', 0]]
# [[['object', 0], ['system', 0], ['object-system', 0], ['objectsystem', 0], ['environ', 0], ['modular', 0], ['distribut', 0], ['modular-distribut', 0], ['modulardistribut', 0], ['structur', 0], ['system', 0], ['structur', 0], ['system-structur', 0], ['systemstructur', 0], ['found', 0], ['system', 0], ['propos', 0], ['design', 0], ['develop', 0], ['design-develop', 0], ['designdevelop', 0], ['implement', 0]], 10]

# %%
[g,l] = glist('52795.key')
[pr,k] = extList(pred_data+'/'+'52795_ranked_list.csv',20)
[sc,k] = extList(phrase_data+'/'+'52795_ranked_list.csv',20)
rec = 0
    #k = 8
prec = 0

#print(g,ext)
r=0
for i in g:
    f=0
    for j in ext:
        for it in i:
            if it in j:
                
                f=1
                r += 1
                break
        if f:
            break
#print(r,l)
r /= l
rec += r

p=0
for i in ext:
    f=0
    for j in g:
        for it in i:
            if it in j:
                print('match',it)
                f=1
                p += 1
                break
        if f:
            break
#print(r,l)
p /= k
prec += p

#print()
# tp=0
# fp=0
# fn=0
# fp=0
# g = glist('52795.key')
# ext = extList('52795_ranked_list.csv',150)
# for i in g:
#     #print(i)
#     if i in ext:
#         print(i)
#         tp=tp+1;
# print(tp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d046da653c86> in <module>
#      10 for i in g:
#      11     f=0
# ---> 12     for j in ext:
#      13         for it in i:
#      14             if it in j:
#
# NameError: name 'ext' is not defined

# %%
mx = 0
x=0
for k in range(1,50):
    print(k)
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
        #print(g,ext)
        tp=0
        le = len(ext)
        r=0
        for i in g:
            f=0
            for j in range(le):
    #             print(i,pr[j])
                if ext[j][1]==1:
                    continue
                for it in i:
                    if it == ext[j][0]:
    #                     print('matched',pr[j][0])
                        ext[j][1]=1
                        f=1
                        tp += 1
                        break
                if f:
                    break
            #print(r,l)
        #r /= l
        rec += tp/l

#         p=0
#         for i in ext:
#             f=0
#             for j in g:
#                 for it in i:
#                     if it in j:
#                         f=1
#                         p += 1
#                         break
#                 if f:
#                     break
#         #print(r,l)
#         p /= k
        prec += tp/k

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
# 1
# 0.1691098406407755 0.8016493055555556 0.2793005594507593 0.2793005594507593 1
# 2
# 0.2782242749382272 0.6675347222222222 0.3927519899762799 0.3927519899762799 2
# 3
# 0.3484442252907752 0.56394675925926 0.43074514098195793 0.43074514098195793 3
# 4
# 0.40406600088784006 0.4927300347222222 0.4440150195626065 0.4440150195626065 4
# 5
# 0.44639256212146705 0.43836805555555675 0.44234391893578584 0.4440150195626065 4
# 6
# 0.48182527533960023 0.395688657407408 0.4345293885129623 0.4440150195626065 4
# 7
# 0.5105479494339321 0.3607390873015922 0.42276447034618647 0.4440150195626065 4
# 8
# 0.5380301818521382 0.3343098958333333 0.41238232347965265 0.4440150195626065 4
# 9
# 0.5654281520422403 0.3137056327160462 0.4035290174649469 0.4440150195626065 4
# 10
# 0.5872698745369698 0.2938802083333329 0.3917312077293833 0.4440150195626065 4
# 11
# 0.6054335341724869 0.27667297979797545 0.3797888289366615 0.4440150195626065 4
# 12
# 0.6227688756081616 0.26164641203703676 0.368481287258309 0.4440150195626065 4
# 13
# 0.6400256106711385 0.24893162393162424 0.3584483221926654 0.4440150195626065 4
# 14
# 0.6552437904398974 0.23728918650793732 0.3484067704244568 0.4440150195626065 4
# 15
# 0.6710259426562459 0.22728587962962457 0.3395585315638604 0.4440150195626065 4
# 16
# 0.6828816978618023 0.2172309027777778 0.32960989016604153 0.4440150195626065 4
# 17
# 0.6949891974774656 0.20861417483660777 0.3209031802987211 0.4440150195626065 4
# 18
# 0.7074552343430016 0.20083429783950638 0.31285459142253097 0.4440150195626065 4
# 19
# 0.7178877685021751 0.19343932748537804 0.3047593509738816 0.4440150195626065 4
# 20
# 0.7291228230681335 0.18706597222222007 0.2977422785953737 0.4440150195626065 4
# 21
# 0.737327715210538 0.18043154761905109 0.28991738061609484 0.4440150195626065 4
# 22
# 0.7460689182180895 0.17453835227272574 0.2828950929276405 0.4440150195626065 4
# 23
# 0.7545431809689196 0.16910099637680698 0.2762838912227784 0.4440150195626065 4
# 24
# 0.7623227038361317 0.16389973958333356 0.2697937056587176 0.4440150195626065 4
# 25
# 0.7692900971197072 0.15901041666666849 0.2635464207201688 0.4440150195626065 4
# 26
# 0.7762526676952973 0.1543803418803421 0.2575411596005449 0.4440150195626065 4
# 27
# 0.783678038928748 0.1502539866255138 0.2521612844575649 0.4440150195626065 4
# 28
# 0.7908087188056746 0.14643787202380965 0.2471160676237591 0.4440150195626065 4
# 29
# 0.7980979522605852 0.1427951388888882 0.24224751783597218 0.4440150195626065 4
# 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-da6a0bef006c> in <module>
#       8     for every_file in (os.listdir(gold_data)):
#       9         #print(every_file)
# ---> 10         [g,l] = glist(every_file)
#      11         [ext,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
#      12         #print(g,ext)
#
# <ipython-input-6-0a8561793eab> in glist(fil)
#      13         for word in row:
#      14             word=word.replace("-"," ")
# ---> 15             gold_list.append(" ".join([ps.stem(i) for i in word.split()]))
#      16
#      17    #print(gold_list)
#
# <ipython-input-6-0a8561793eab> in <listcomp>(.0)
#      13         for word in row:
#      14             word=word.replace("-"," ")
# ---> 15             gold_list.append(" ".join([ps.stem(i) for i in word.split()]))
#      16
#      17    #print(gold_list)
#
# ~/.local/lib/python3.6/site-packages/nltk/stem/porter.py in stem(self, word)
#     670         stem = self._step2(stem)
#     671         stem = self._step3(stem)
# --> 672         stem = self._step4(stem)
#     673         stem = self._step5a(stem)
#     674         stem = self._step5b(stem)
#
# ~/.local/lib/python3.6/site-packages/nltk/stem/porter.py in _step4(self, word)
#     598                 ('ous', '', measure_gt_1),
#     599                 ('ive', '', measure_gt_1),
# --> 600                 ('ize', '', measure_gt_1),
#     601             ],
#     602         )
#
# ~/.local/lib/python3.6/site-packages/nltk/stem/porter.py in _apply_rule_list(self, word, rules)
#     256         or None if the rule is unconditional.
#     257         """
# --> 258         for rule in rules:
#     259             suffix, replacement, condition = rule
#     260             if suffix == '*d' and self._ends_double_consonant(word):
#
# KeyboardInterrupt:

# %%
mx = 0
x=0
for k in range(1,50):
    print(k)
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(phrase_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
        #print(g,ext)
        tp=0
        le = len(ext)
        r=0
        for i in g:
            f=0
            for j in range(le):
    #             print(i,pr[j])
                if ext[j][1]==1:
                    continue
                for it in i:
                    if it == ext[j][0]:
    #                     print('matched',pr[j][0])
                        ext[j][1]=1
                        f=1
                        tp += 1
                        break
                if f:
                    break
            #print(r,l)
        #r /= l
        rec += tp/l

#         p=0
#         for i in ext:
#             f=0
#             for j in g:
#                 for it in i:
#                     if it in j:
#                         f=1
#                         p += 1
#                         break
#                 if f:
#                     break
#         #print(r,l)
#         p /= k
        prec += tp/k

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
# 1
# 0.13970137568992014 0.6306423611111112 0.22873322961361858 0.22873322961361858 1
# 2
# 0.24934510313177607 0.5748697916666666 0.3478242589283002 0.3478242589283002 2
# 3
# 0.333932875561195 0.5189525462962963 0.4063742013249754 0.4063742013249754 3
# 4
# 0.39625456391885616 0.4666883680555556 0.42859704603349214 0.42859704603349214 4
# 5
# 0.44866069850322876 0.42769097222222213 0.4379249489691751 0.4379249489691751 5
# 6
# 0.48874307579248544 0.3922887731481502 0.43523607419601074 0.4379249489691751 5
# 7
# 0.5238583445606625 0.36154513888889456 0.4278240180496906 0.4379249489691751 5
# 8
# 0.5520784485805097 0.3356119791666667 0.41745215447144274 0.4379249489691751 5
# 9
# 0.5768072362669916 0.3131751543209857 0.40594442573640876 0.4379249489691751 5
# 10
# 0.5975743696500229 0.29370659722222103 0.3938410921374016 0.4379249489691751 5
# 11
# 0.6160172060209445 0.27667297979797556 0.3818465100303242 0.4379249489691751 5
# 12
# 0.6351713565026452 0.26226128472222215 0.3712386831568355 0.4379249489691751 5
# 13
# 0.6523844757625145 0.24943242521367548 0.36088443626428024 0.4379249489691751 5
# 14
# 0.6676969122115827 0.23753720238095338 0.3504129020513786 0.4379249489691751 5
# 15
# 0.6810704849604073 0.2270254629629577 0.3405374564485803 0.4379249489691751 5
# 16
# 0.6975159476198008 0.2180718315972222 0.3322643305610735 0.4379249489691751 5
# 17
# 0.7094656448925898 0.20925245098039905 0.3231838487715776 0.4379249489691751 5
# 18
# 0.7194437236556395 0.2010754243827169 0.31430623113450323 0.4379249489691751 5
# 19
# 0.729997566360913 0.193827668128653 0.30632141393172885 0.4379249489691751 5
# 20
# 0.7381913467406509 0.18663194444444203 0.2979381850077041 0.4379249489691751 5
# 21
# 0.7475371495475667 0.18026620370370763 0.29048328744277585 0.4379249489691751 5
# 22
# 0.7556727248582459 0.17430160984848353 0.2832658226055651 0.4379249489691751 5
# 23
# 0.7638678527452676 0.1687424516908165 0.2764218530010247 0.4379249489691751 5
# 24
# 0.7708123161678478 0.16346571180555558 0.269729952237415 0.4379249489691751 5
# 25
# 0.7770377152054848 0.15857638888889047 0.26339884011695214 0.4379249489691751 5
# 26
# 0.7834028625173234 0.1540130876068377 0.2574189049809687 0.4379249489691751 5
# 27
# 0.7900330898202909 0.1497074331275717 0.25171592173513613 0.4379249489691751 5
# 28
# 0.7953727800230609 0.1455233134920638 0.246032018217726 0.4379249489691751 5
# 29
# 0.8005851497498299 0.1415229885057461 0.24052695936945562 0.4379249489691751 5
# 30
# 0.8052020772568684 0.1376736111111098 0.23514250927818223 0.4379249489691751 5
# 31
# 0.809441761670671 0.1341145833333328 0.23010378802253778 0.4379249489691751 5
# 32
# 0.813801390483163 0.1308051215277778 0.22538356115078687 0.4379249489691751 5
# 33
# 0.8173431308351118 0.12760416666666777 0.22074540954119876 0.4379249489691751 5
# 34
# 0.8209207413118491 0.1245276756535972 0.21625156904806295 0.4379249489691751 5
# 35
# 0.8255371643853033 0.12178819444444684 0.2122621964252588 0.4379249489691751 5
# 36
# 0.8290892472077056 0.11893566743827148 0.20802888502010736 0.4379249489691751 5
# 37
# 0.8344346209490878 0.11653059309309405 0.20450203612241738 0.4379249489691751 5
# 38
# 0.8382295540287017 0.11402366593567141 0.20074073711097853 0.4379249489691751 5
# 39
# 0.8415722443811959 0.11161191239316454 0.19708570887341775 0.4379249489691751 5
# 40
# 0.8443348030031297 0.10924479166666538 0.19345879497963123 0.4379249489691751 5
# 41
# 0.8476200096067338 0.10702489837398305 0.190052750775784 0.4379249489691751 5
# 42
# 0.850191144339125 0.10487971230158939 0.18672499951108923 0.4379249489691751 5
# 43
# 0.8528049104763665 0.10284439599483314 0.18355312001058383 0.4379249489691751 5
# 44
# 0.8564060534533356 0.10104955808080786 0.18076964027716125 0.4379249489691751 5
# 45
# 0.8595694467919963 0.09921875000000219 0.1779024946995614 0.4379249489691751 5
# 46
# 0.862000403960995 0.09737318840579443 0.174980275480992 0.4379249489691751 5
# 47
# 0.8644553672110555 0.09561539598108934 0.17218572924571138 0.4379249489691751 5
# 48
# 0.8672082855889736 0.09398509837962972 0.16959054732605605 0.4379249489691751 5
# 49
# 0.8697979808278942 0.0923416241496599 0.1669582206495205 0.4379249489691751 5

# %%
k = 20
dif = []

# %%
every_file = '629280.key'
mx = 0
mn = 100
for every_file in (os.listdir(gold_data)):
    #print(every_file)
    [g,l] = glist(every_file)
    [sc,k] = extList(phrase_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
    [pr,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
#     print(len(sc),len(pr))
#     print(g)
#     print(pr) 
#     print(sc)
    tp = 0
    p=0
    le = len(pr)
    #print("US")
    for i in g:
        f=0
        for j in range(le):
#             print(i,pr[j])
            if pr[j][1]==1:
                continue
            for it in i:
                if it == pr[j][0]:
#                     print('matched',i,pr[j][0])
                    pr[j][1]=1
                    f=1
                    tp += 1
                    break
            if f:
                break
#     print(tp)
    p = tp
    tp = 0
#     print('sCAKE')
    le = len(sc)
    #print("US")
    for i in g:
        f=0
        for j in range(le):
            if sc[j][1]==1:
                continue
            for it in i:
                if it == sc[j][0]:
#                     print('matched',i,sc[j][0])
                    sc[j][1]=1
                    f=1
                    tp += 1
                    break
            if f:
                break 
#     print(k)
    dif.append(p-tp)
#     print(p-tp)
    if (p-tp > mx):
        mx = p-tp
        print('max',p-tp, every_file)
    
    if (p-tp < mn):
        mn = p-tp
        print('min',p-tp,every_file)
# Out:
# min 0 311896.key
# min -1 509912.key
# max 1 380322.key
# min -2 255519.key
# max 2 1011810.key
# max 3 628552.key
# max 4 354387.key
# max 5 244528.key
# max 7 631135.key
# min -3 290837.key

# %%
every_file = '631135.key'
k=20
[g,l] = glist(every_file)
[sc,k] = extList(phrase_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
[pr,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
#     print(len(sc),len(pr))
#     print(g)
# print(pr) 
#     print(sc)
tp = 0
p=0
le = len(pr)
print("US")
for i in g:
    f=0
    for j in range(le):
#             print(i,pr[j])
        if pr[j][1]==1:
            continue
        for it in i:
            if it == pr[j][0]:
                print('matched',i,pr[j][0])
                pr[j][1]=1
                f=1
                tp += 1
                break
        if f:
            break
print(tp)
p = tp
tp = 0
print('sCAKE')
le = len(sc)
#print("US")
for i in g:
    f=0
    for j in range(le):
        if sc[j][1]==1:
            continue
        for it in i:
            if it == sc[j][0]:
                print('matched',i,sc[j][0])
                sc[j][1]=1
                f=1
                tp += 1
                break
        if f:
            break
print(tp)
# Out:
# US
# matched ['simul'] simul
# matched ['stochast', 'process', 'stochast-process', 'stochastprocess'] stochast
# matched ['petri', 'net', 'petri-net', 'petrinet'] petri
# matched ['stochast', 'petri', 'net', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'stochast-petri-net', 'stochastpetrinet'] stochast-petri
# matched ['gener', 'stochast', 'petri', 'net', 'gener-stochast', 'generstochast', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'gener-stochast-petri', 'generstochastpetri', 'stochast-petri-net', 'stochastpetrinet', 'gener-stochast-petri-net', 'generstochastpetrinet'] stochastpetri
# matched ['PH', 'type', 'distribut', 'PH-type', 'PHtype', 'type-distribut', 'typedistribut', 'PH-type-distribut', 'PHtypedistribut'] distribut
# matched ['spn', 'class', 'spn-class', 'spnclass'] spn
# matched ['continu', 'time', 'case', 'continu-time', 'continutime', 'time-case', 'timecase', 'continu-time-case', 'continutimecase'] time
# matched ['determinist', 'petri', 'net', 'determinist-petri', 'deterministpetri', 'petri-net', 'petrinet', 'determinist-petri-net', 'deterministpetrinet'] petri
# matched ['distribut', 'fire', 'time', 'distribut-fire', 'distributfire', 'fire-time', 'firetime', 'distribut-fire-time', 'distributfiretime'] fire
# matched ['gener', 'time', 'petri', 'net', 'gener-time', 'genertime', 'time-petri', 'timepetri', 'petri-net', 'petrinet', 'gener-time-petri', 'genertimepetri', 'time-petri-net', 'timepetrinet', 'gener-time-petri-net', 'genertimepetrinet'] net
# matched ['model', 'power', 'model-power', 'modelpower'] model
# matched ['semimarkovian', 'stochast', 'petri', 'net', 'semimarkovian-stochast', 'semimarkovianstochast', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'semimarkovian-stochast-petri', 'semimarkovianstochastpetri', 'stochast-petri-net', 'stochastpetrinet', 'semimarkovian-stochast-petri-net', 'semimarkovianstochastpetrinet'] stochast
# matched ['state', 'discret', 'state-discret', 'statediscret'] discret
# matched ['stochast', 'petri', 'net', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'stochast-petri-net', 'stochastpetrinet'] stochast-petri
# matched ['stochast', 'process', 'stochast-process', 'stochastprocess'] stochast
# matched ['time', 'petri', 'net', 'time-petri', 'timepetri', 'petri-net', 'petrinet', 'time-petri-net', 'timepetrinet'] petri-net
# 17
# sCAKE
# matched ['markov', 'process', 'markov-process', 'markovprocess'] process
# matched ['stochast', 'process', 'stochast-process', 'stochastprocess'] stochast
# matched ['petri', 'net', 'petri-net', 'petrinet'] petri
# matched ['stochast', 'petri', 'net', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'stochast-petri-net', 'stochastpetrinet'] net
# matched ['gener', 'stochast', 'petri', 'net', 'gener-stochast', 'generstochast', 'stochast-petri', 'stochastpetri', 'petri-net', 'petrinet', 'gener-stochast-petri', 'generstochastpetri', 'stochast-petri-net', 'stochastpetrinet', 'gener-stochast-petri-net', 'generstochastpetrinet'] gener
# matched ['PH', 'type', 'distribut', 'PH-type', 'PHtype', 'type-distribut', 'typedistribut', 'PH-type-distribut', 'PHtypedistribut'] distribut
# matched ['spn', 'class', 'spn-class', 'spnclass'] spn
# matched ['continu', 'time', 'case', 'continu-time', 'continutime', 'time-case', 'timecase', 'continu-time-case', 'continutimecase'] time
# matched ['distribut', 'fire', 'time', 'distribut-fire', 'distributfire', 'fire-time', 'firetime', 'distribut-fire-time', 'distributfiretime'] fire
# matched ['model', 'power', 'model-power', 'modelpower'] model
# 10

# %%
print("mean",sum(dif)/2304)
print("max",max(dif))
print("min",min(dif))
# Out:
# mean 0.008680555555555556
# max 7
# min -3
