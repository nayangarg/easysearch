# %%
class Kw:
    def __init__(self, val, f):
        self.val = val
        self.f = f

# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
from read_write_create import *
import csv
import pandas as pd
import os
import re
from nltk.util import ngrams

cwd=os.getcwd()
path=cwd
phrase_data= "/home/nayan/coding/Major/sCAKE/venv/SCScore_W"
gold_data= "/home/nayan/coding/Major/EasySearch/venv/keys"
pred_data = "/home/nayan/coding/Major/EasySearch/venv/SCScore_W"

ps = PorterStemmer()

# %%
def generate_ngrams(s, n, sep):
    
    tokens = [token for token in s.split(sep) if token != ""]
    
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def glist(fil):
    gold_list=[]
    #keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(gold_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    l = len(reader)
    
    for row in reader:
        for word in row:
            word=word.replace("-"," ")            
            gold_list.append(" ".join([ps.stem(i) for i in word.split()]))

   #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split(" ")
        t = []
        for i in range(1,len(tokens)+1):
            ng = generate_ngrams(word,i," ")
            #print(ng)
            for j in ng:
                t.append(j)
        gold.append(t)
    #print(gold)
#     g = []
#     for i in gold:
#         for j in i:
#             g.append(j)
#     print(g)
    #gold = []
    res = []
    for i in gold:
        g = []
        for j in i:
            if ' ' in j:
                g.append(j.replace(" ","-"))
                g.append(j.replace(" ",""))
            else:
                g.append(j)
        res.append(g)
    #gold = set(gold)
            
    #print(res)

    return [res, l]
    
#print(gold)

# %%
len(glist('52795.key'))
# Out:
# [['databas', 'theori', 'databas theori'], ['file', 'organis', 'file organis'], ['boolean', 'algebra', 'boolean algebra'], ['close', 'form', 'bound', 'close form', 'form bound', 'close form bound'], ['databas', 'access', 'databas access'], ['distribut', 'inform', 'distribut inform'], ['rule', 'base', 'system', 'architectur', 'rule base', 'base system', 'system architectur', 'rule base system', 'base system architectur', 'rule base system architectur'], ['set', 'intersect', 'set intersect'], ['set', 'theori', 'set theori'], ['statist', 'analysi', 'statist analysi'], ['union', 'size', 'union size']]
# [['databas', 'theori', 'databas-theori', 'databastheori'], ['file', 'organis', 'file-organis', 'fileorganis'], ['boolean', 'algebra', 'boolean-algebra', 'booleanalgebra'], ['close', 'form', 'bound', 'close-form', 'closeform', 'form-bound', 'formbound', 'close-form-bound', 'closeformbound'], ['databas', 'access', 'databas-access', 'databasaccess'], ['distribut', 'inform', 'distribut-inform', 'distributinform'], ['rule', 'base', 'system', 'architectur', 'rule-base', 'rulebase', 'base-system', 'basesystem', 'system-architectur', 'systemarchitectur', 'rule-base-system', 'rulebasesystem', 'base-system-architectur', 'basesystemarchitectur', 'rule-base-system-architectur', 'rulebasesystemarchitectur'], ['set', 'intersect', 'set-intersect', 'setintersect'], ['set', 'theori', 'set-theori', 'settheori'], ['statist', 'analysi', 'statist-analysi', 'statistanalysi'], ['union', 'size', 'union-size', 'unionsize']]
# 2

# %%
def extList(fil, k):
    #gold_list=[]
    gold_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for i in range(1,k+1):
       # if(int(reader[i][0])<=len(reader[:k])):
        gold_list.append(reader[i][4])

    #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split("-")
        t = []
        for i in range(1,len(tokens)+1):
            ng = generate_ngrams(word,i,"-")
            #print(ng)
            for j in ng:
                t.append(j)
        gold.append(t)
#     print(gold)
#     g = []
#     for i in gold:
#         for j in i:
#             g.append(j)
#     print(g)
    #gold = []
    g = []
    for i in gold:
#         g = []
        for j in i:
            if ' ' in j:
                g.append(j.replace(" ","-"))
                g.append(j.replace(" ",""))
            else:
                g.append(j)
#         res.append(g)
    g = set(g)
    #res = set(res)
    res = []  
    for i in g:
        res.append([i,0])
#     print(res)

    return [res, k]
    
#print(gold)

# %%
a = extList(pred_data+'/'+'52795_ranked_list.csv', 10)
# Out:
# [['boundsetintersect', 0], ['catalogquick', 0], ['requir', 0], ['quickclosedform', 0], ['setintersect', 0], ['boundset', 0], ['intersect-union', 0], ['intersectunion', 0], ['intersect', 0], ['data', 0], ['catalogquickclosedform', 0], ['quick', 0], ['setintersectunion', 0], ['quick-closedform', 0], ['catalog', 0], ['set-intersect-union', 0], ['inform', 0], ['union', 0], ['set-intersect', 0], ['statist', 0], ['bound-set', 0], ['size', 0], ['method', 0], ['catalog-quick', 0], ['bound', 0], ['unionsize', 0], ['bound-set-intersect', 0], ['closedform', 0], ['union-size', 0], ['set', 0], ['catalog-quick-closedform', 0]]

# %%
[g,l] = glist('52795.key')
[pr,k] = extList(pred_data+'/'+'52795_ranked_list.csv',20)
[sc,k] = extList(phrase_data+'/'+'52795_ranked_list.csv',20)
rec = 0
    #k = 8
prec = 0

#print(g,ext)
r=0
for i in g:
    f=0
    for j in ext:
        for it in i:
            if it in j:
                
                f=1
                r += 1
                break
        if f:
            break
#print(r,l)
r /= l
rec += r

p=0
for i in ext:
    f=0
    for j in g:
        for it in i:
            if it in j:
                print('match',it)
                f=1
                p += 1
                break
        if f:
            break
#print(r,l)
p /= k
prec += p

#print()
# tp=0
# fp=0
# fn=0
# fp=0
# g = glist('52795.key')
# ext = extList('52795_ranked_list.csv',150)
# for i in g:
#     #print(i)
#     if i in ext:
#         print(i)
#         tp=tp+1;
# print(tp)
# Out:
# match set
# match inform
# match bound
# match bound
# match union
# match statist
# match distribut
# match rule
# match databas
# match distribut
# match bound

# %%
mx = 0
x=0
for k in range(1,50):
    print(k)
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
        #print(g,ext)
        tp=0
        le = len(ext)
        r=0
        for i in g:
            f=0
            for j in range(le):
    #             print(i,pr[j])
                if ext[j][1]==1:
                    continue
                for it in i:
                    if it == ext[j][0]:
    #                     print('matched',pr[j][0])
                        ext[j][1]=1
                        f=1
                        tp += 1
                        break
                if f:
                    break
            #print(r,l)
        #r /= l
        rec += tp/l

#         p=0
#         for i in ext:
#             f=0
#             for j in g:
#                 for it in i:
#                     if it in j:
#                         f=1
#                         p += 1
#                         break
#                 if f:
#                     break
#         #print(r,l)
#         p /= k
        prec += tp/k

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
# 1
# 0.16995963663839592 0.8046875 0.280643917098379 0.280643917098379 1
# 2
# 0.2680088492789541 0.6440972222222222 0.37851684304093774 0.37851684304093774 2
# 3
# 0.33621077222521856 0.5399305555555547 0.4143862714275398 0.4143862714275398 3
# 4
# 0.3860602262681972 0.4683159722222222 0.4232284806636013 0.4232284806636013 4
# 5
# 0.42517958592560323 0.41588541666666784 0.4204811487954682 0.4232284806636013 4
# 6
# 0.45766612475813506 0.3743489583333337 0.4118358922799152 0.4232284806636013 4
# 7
# 0.4898646614591881 0.3449900793650841 0.4048571330339434 0.4232284806636013 4
# 8
# 0.5175132453417486 0.3198784722222222 0.395373736812811 0.4232284806636013 4
# 9
# 0.5428140581957228 0.29861111111110805 0.3852756369959436 0.4232284806636013 4
# 10
# 0.563785390110148 0.2807291666666663 0.3748212543511919 0.4232284806636013 4
# 11
# 0.5834928609059968 0.2649936868686835 0.3644652349022194 0.4232284806636013 4
# 12
# 0.6018110391449019 0.25075954861111094 0.35401142542896713 0.4232284806636013 4
# 13
# 0.6165294935142125 0.23761351495726407 0.34302391654740305 0.4232284806636013 4
# 14
# 0.6320578315887476 0.2268415178571452 0.33386207122775224 0.4232284806636013 4
# 15
# 0.6463400084238343 0.2170428240740686 0.3249623584349114 0.4232284806636013 4
# 16
# 0.6573940955662996 0.2075737847222222 0.3155210351284297 0.4232284806636013 4
# 17
# 0.6701312566617466 0.19949959150327423 0.3074658913944716 0.4232284806636013 4
# 18
# 0.682547858185846 0.19208140432098766 0.29979502570232214 0.4232284806636013 4
# 19
# 0.6913637751130266 0.18469024122806832 0.2915074641978629 0.4232284806636013 4
# 20
# 0.7016516574161952 0.17832031249999789 0.28436983698131535 0.4232284806636013 4
# 21
# 0.7097873663046834 0.1720610119047653 0.276978980744002 0.4232284806636013 4
# 22
# 0.7182835209920426 0.16664693813131146 0.27052916587836884 0.4232284806636013 4
# 23
# 0.7259647727038673 0.16143946256038202 0.264139741699977 0.4232284806636013 4
# 24
# 0.7341925099293127 0.1567021122685185 0.2582786207280545 0.4232284806636013 4
# 25
# 0.7416919768545732 0.15211805555555716 0.2524579882730711 0.4232284806636013 4
# 26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-da6a0bef006c> in <module>
#       9         #print(every_file)
#      10         [g,l] = glist(every_file)
# ---> 11         [ext,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
#      12         #print(g,ext)
#      13         tp=0
#
# <ipython-input-4-6a1ad2c46286> in extList(fil, k)
#      22             for j in ng:
#      23                 t.append(j)
# ---> 24         gold.append(t)
#      25 #     print(gold)
#      26 #     g = []
#
# KeyboardInterrupt:

# %%
mx = 0
x=0
for k in range(1,50):
    print(k)
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(phrase_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
        #print(g,ext)
        tp=0
        le = len(ext)
        r=0
        for i in g:
            f=0
            for j in range(le):
    #             print(i,pr[j])
                if ext[j][1]==1:
                    continue
                for it in i:
                    if it == ext[j][0]:
    #                     print('matched',pr[j][0])
                        ext[j][1]=1
                        f=1
                        tp += 1
                        break
                if f:
                    break
            #print(r,l)
        #r /= l
        rec += tp/l

#         p=0
#         for i in ext:
#             f=0
#             for j in g:
#                 for it in i:
#                     if it in j:
#                         f=1
#                         p += 1
#                         break
#                 if f:
#                     break
#         #print(r,l)
#         p /= k
        prec += tp/k

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
# 1
# 0.13970137568992014 0.6306423611111112 0.22873322961361858 0.22873322961361858 1
# 2
# 0.2499044267602471 0.576171875 0.3486067856696402 0.3486067856696402 2
# 3
# 0.33447861926072175 0.5198206018518516 0.4070444473641245 0.4070444473641245 3
# 4
# 0.3975537654356429 0.4682074652777778 0.4299976349665692 0.4299976349665692 4
# 5
# 0.44982088169274737 0.42890625000000027 0.4391146707098366 0.4391146707098366 5
# 6
# 0.4905293111705559 0.39380787037037207 0.43687929766725947 0.4391146707098366 5
# 7
# 0.5263420158026982 0.3632812500000055 0.4298677716253264 0.4391146707098366 5
# 8
# 0.5546671291072425 0.3372395833333333 0.4194512921580584 0.4391146707098366 5
# 9
# 0.5790944451603584 0.31467013888888684 0.4077667268103623 0.4391146707098366 5
# 10
# 0.6000338274461074 0.29522569444444335 0.395740897620056 0.4391146707098366 5
# 11
# 0.6190194833865414 0.2782512626262585 0.3839263758635953 0.4391146707098366 5
# 12
# 0.6380879669225114 0.2637080439814812 0.3731862363786168 0.4391146707098366 5
# 13
# 0.6549453980337234 0.2506343482905986 0.36253419683553756 0.4391146707098366 5
# 14
# 0.6704172363511778 0.2387462797619058 0.35210304467869447 0.4391146707098366 5
# 15
# 0.6845509932241572 0.22838541666666176 0.34250241774402157 0.4391146707098366 5
# 16
# 0.700883223098104 0.21937391493055555 0.33415768312223326 0.4391146707098366 5
# 17
# 0.7128947677634696 0.2105034722222291 0.32503164386710154 0.4391146707098366 5
# 18
# 0.723045225507492 0.20235339506172925 0.31621109630489314 0.4391146707098366 5
# 19
# 0.7340172770294118 0.19510690789473478 0.3082727660871582 0.4391146707098366 5
# 20
# 0.7421955299196642 0.18784722222221975 0.2998128168196036 0.4391146707098366 5
# 21
# 0.7499675496610246 0.1811342592592632 0.2917936906037396 0.4391146707098366 5
# 22
# 0.7581076751246529 0.17507102272727149 0.28445288416244435 0.4391146707098366 5
# 23
# 0.7666332921116951 0.16955389492753148 0.27769160368397017 0.4391146707098366 5
# 24
# 0.774012988944769 0.16435185185185192 0.27113221331367227 0.4391146707098366 5
# 25
# 0.7804461952214632 0.15951388888889037 0.26488786018215227 0.4391146707098366 5
# 26
# 0.7867546777956475 0.1548811431623932 0.2588122948877919 0.4391146707098366 5
# 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6993cd54aacf> in <module>
#      20                 if ext[j][1]==1:
#      21                     continue
# ---> 22                 for it in i:
#      23                     if it == ext[j][0]:
#      24     #                     print('matched',pr[j][0])
#
# KeyboardInterrupt:

# %%
k = 20
dif = []

# %%
every_file = '587833.key'
mx = 0
mn = 100
for k in range(1,50):
    #print(every_file)
    [g,l] = glist(every_file)
    [sc,k] = extList(phrase_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
    [pr,k] = extList(pred_data + '/' + every_file[:-4]+'_ranked_list.csv',k)
#     print(len(sc),len(pr))
#     print(g)
#     print(pr) 
#     print(sc)
    tp = 0
    p=0
    le = len(pr)
    #print("US")
    for i in g:
        f=0
        for j in range(le):
#             print(i,pr[j])
            if pr[j][1]==1:
                continue
            for it in i:
                if it == pr[j][0]:
#                     print('matched',i,pr[j][0])
                    pr[j][1]=1
                    f=1
                    tp += 1
                    break
            if f:
                break
#     print(tp)
    p = tp
    tp = 0
#     print('sCAKE')
    le = len(sc)
    #print("US")
    for i in g:
        f=0
        for j in range(le):
            if sc[j][1]==1:
                continue
            for it in i:
                if it == sc[j][0]:
#                     print('matched',i,sc[j][0])
                    sc[j][1]=1
                    f=1
                    tp += 1
                    break
            if f:
                break 
    print(k)
#     dif.append(p-tp)
    print(p-tp)
#     if (p-tp > mx):
#         mx = p-tp
#         print(every_file)
# Out:
# 1
# -1
# 2
# -2
# 3
# -2
# 4
# -1
# 5
# -2
# 6
# -2
# 7
# -3
# 8
# -2
# 9
# -3
# 10
# -1
# 11
# -2
# 12
# -3
# 13
# -3
# 14
# -3
# 15
# -4
# 16
# -5
# 17
# -5
# 18
# -5
# 19
# -5
# 20
# -5
# 21
# -3
# 22
# -2
# 23
# -2
# 24
# -2
# 25
# -2
# 26
# -2
# 27
# -2
# 28
# -2
# 29
# -3
# 30
# -3
# 31
# -3
# 32
# -3
# 33
# -3
# 34
# -3
# 35
# -3
# 36
# -3
# 37
# -3
# 38
# -3
# 39
# -3
# 40
# -2
# 41
# 0
# 42
# 0
# 43
# -1
# 44
# -1
# 45
# -1
# 46
# -1
# 47
# -1
# 48
# -1
# 49
# -1

# %%
print("mean",sum(dif)/2304)
print("max",max(dif))
print("min",min(dif))
# Out:
# mean -0.19053819444444445
# max 5
# min -5
