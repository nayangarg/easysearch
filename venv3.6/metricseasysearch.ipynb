# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
from read_write_create import *
import csv
import pandas as pd
import os
import re
from nltk.util import ngrams

cwd=os.getcwd()
path=cwd
phrase_data= "/home/nayan/coding/Major/EasySearch/venv/SCScore_W"
gold_data= "/home/nayan/coding/Major/EasySearch/venv/keys"

ps = PorterStemmer()

# %%
def generate_ngrams(s, n, sep):
    
    tokens = [token for token in s.split(sep) if token != ""]
    
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def glist(fil):
    gold_list=[]
    #keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(gold_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    l = len(reader)
    
    for row in reader:
        for word in row:
            word=word.replace("-"," ")            
            gold_list.append(" ".join([ps.stem(i) for i in word.split()]))

    #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split(" ")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i," "))

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    #print(gold)

    return [gold, l]
    
#print(gold)

# %%
def extList(fil, k):
    #gold_list=[]
    keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(phrase_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for i in range(1,k+1):
#         if(int(reader[i][0])<=len(reader[:k])):
        keyword_list.append(reader[i][4])

    #print(gold_list)
    gold=[]
    for word in keyword_list:
        tokens=word.split("-")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i,'-'))
            
    #print(gold)

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    #print(gold)

    return [gold, k]
    
#print(gold)

# %%
[g,l] = glist('52795.key')
[ext,k] = extList('52795_ranked_list.csv',14)
rec = 0
prec=0

for i in ext:
    if i in g:
        prec += 1

prec /= k
print(prec)

for i in g:
    if i in ext:
        rec += 1

rec /= l

print(rec)

# tp=0
# fp=0
# fn=0
# fp=0
# g = glist('52795.key')
# ext = extList('52795_ranked_list.csv',150)
# for i in g:
#     #print(i)
#     if i in ext:
#         print(i)
#         tp=tp+1;
# print(tp)
# Out:
# 0.8571428571428571
# 1.0909090909090908

# %%
a = extList('52795_ranked_list.csv')
# Out:
# {'requir', 'attribut', 'univers', 'set', 'setsize', 'intersect', 'size', 'frequenc', 'count', 'absolut', 'gener', 'data', 'assum', 'import', 'absolut-bound', 'method', 'distribut', 'complement', 'bound', 'inform', 'formula', 'correl', 'set-size', 'level', 'absolutbound', 'valu'}

# %%
len(glist('52795.key'))
# Out:
# {'databas-theori', 'rule-base-system-architectur', 'architectur', 'set-intersect', 'distribut-inform', 'base-system-architectur', 'rule-base', 'fileorganis', 'settheori', 'rule-base-system', 'boolean', 'system', 'rulebasesystem', 'set', 'statist', 'intersect', 'size', 'systemarchitectur', 'form', 'access', 'union', 'databas-access', 'basesystem', 'analysi', 'unionsize', 'rule', 'set-theori', 'close-form', 'closeformbound', 'closeform', 'organis', 'form-bound', 'system-architectur', 'base-system', 'databasaccess', 'distribut', 'booleanalgebra', 'bound', 'base', 'basesystemarchitectur', 'databastheori', 'rulebasesystemarchitectur', 'statistanalysi', 'close', 'distributinform', 'rulebase', 'algebra', 'formbound', 'databas', 'inform', 'setintersect', 'close-form-bound', 'union-size', 'statist-analysi', 'boolean-algebra', 'file', 'theori', 'file-organis'}
# 58

# %%
mx = 0
x=0
for k in range(1,1000):
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(every_file[:-4]+'_ranked_list.csv',k)
        
        l1 = len(g)
        l2 = len(ext)
        #print(g,ext)
        r=0
        for i in g:
            if i in ext:
                #print(i)
                r += 1
        #print(r,l)
        r /= l1
        rec += r

        p=0
        for i in ext:
            if i in g:
                #print(i)
                p += 1
        #print(r,l)
        p /= l2
        prec += p

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
# 0.07262149697939341 0.4032419463734552 0.12307746770457734 0.12307746770457734 1
# 0.12178361835381958 0.3461856026060225 0.18018165904537878 0.18018165904537878 2
# 0.15661707387820956 0.3131572935159312 0.20880568365678978 0.20880568365678978 3
# 0.1803631751651123 0.2924982263754535 0.2231347649326576 0.2231347649326576 4
# 0.20125556790528157 0.27484891631528624 0.23236443501153028 0.23236443501153028 5
# 0.21866767096517759 0.2589931410146089 0.23712821115422353 0.23712821115422353 6
# 0.23497147258396822 0.24781768647144162 0.24122367137023346 0.24122367137023346 7
# 0.25002164965710144 0.23717132181003636 0.2434270139478001 0.2434270139478001 8
# 0.2656693832284771 0.22888844564904254 0.24591119029182565 0.24591119029182565 9
# 0.2769206711320869 0.2204008421007527 0.2454490605719782 0.24591119029182565 9
# 0.2894949426593667 0.21300499664081585 0.24542836512405994 0.24591119029182565 9
# 0.2991762330113593 0.2058146002744729 0.2438651664554205 0.24591119029182565 9
# 0.30813971027210973 0.1995262709106708 0.2422142494828802 0.24591119029182565 9
# 0.3169427821053326 0.19371955341353955 0.24046423609724304 0.24591119029182565 9
# 0.32448408249621363 0.18824298186951094 0.23826263719408572 0.24591119029182565 9
# 0.33283853099306976 0.1837294791749696 0.2367635964481265 0.24591119029182565 9
# 0.339976734771235 0.17906920899149756 0.234581796477063 0.24591119029182565 9
# 0.3478923421117516 0.1746507864520386 0.23255370831286998 0.24591119029182565 9
# 0.3550511419609428 0.17051548001291011 0.23038645670924676 0.24591119029182565 9
# 0.3614233161057915 0.16684499049737814 0.22829940387281172 0.24591119029182565 9
# 0.3683733225885732 0.16347388906638782 0.22645383242482356 0.24591119029182565 9
# 0.37386718914321243 0.15993272801274472 0.22403000657139946 0.24591119029182565 9
# 0.3796420592638443 0.15668963694437985 0.22182532509424469 0.24591119029182565 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0e0acc99863e> in <module>
#       8         #print(every_file)
#       9         [g,l] = glist(every_file)
# ---> 10         [ext,k] = extList(every_file[:-4]+'_ranked_list.csv',k)
#      11
#      12         l1 = len(g)
#
# <ipython-input-4-6973a0baac4e> in extList(fil, k)
#       6     with open(phrase_data+'/'+fil, "r") as f:
#       7         reader = csv.reader(f)
# ----> 8         reader=list(reader)
#       9     #print(reader)
#      10     for i in range(1,k+1):
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     316         raise NotImplementedError
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
#
# KeyboardInterrupt:
