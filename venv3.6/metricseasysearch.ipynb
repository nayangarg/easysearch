# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
from read_write_create import *
import csv
import pandas as pd
import os
import re
from nltk.util import ngrams

cwd=os.getcwd()
path=cwd
phrase_data= "/home/nayan/coding/Major/EasySearch/venv/SCScore_W"
gold_data= "/home/nayan/coding/Major/EasySearch/venv/keys"

ps = PorterStemmer()

# %%
def generate_ngrams(s, n, sep):
    
    tokens = [token for token in s.split(sep) if token != ""]
    
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
def glist(fil):
    gold_list=[]
    #keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(gold_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    l = len(reader)
    
    for row in reader:
        for word in row:
            word=word.replace("-"," ")            
            gold_list.append(" ".join([ps.stem(i) for i in word.split()]))

    #print(gold_list)
    gold=[]
    for word in gold_list:
        tokens=word.split(" ")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i," "))

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    #print(gold)

    return [gold, l]
    
#print(gold)

# %%
def extList(fil, k):
    #gold_list=[]
    keyword_list=[]
    # for every_file in (os.listdir(gold_data)):
        #file_name = every_file[:-4]
    with open(phrase_data+'/'+fil, "r") as f:
        reader = csv.reader(f)
        reader=list(reader)
    #print(reader)
    for i in range(1,len(reader)):
        if(int(reader[i][0])<=len(reader[:k])):
            keyword_list.append(reader[i][4])

    #print(gold_list)
    gold=[]
    for word in keyword_list:
        tokens=word.split("-")
        for i in range(1,len(tokens)+1):
            gold.append(generate_ngrams(word,i,'-'))
            
    #print(gold)

    g = []
    for i in gold:
        for j in i:
            g.append(j)

    gold = []
    for i in g:
    #     for j in range(0,len(gold[i])):
        if ' ' in i:
            gold.append(i.replace(" ","-"))
            gold.append(i.replace(" ",""))
        else:
            gold.append(i)
            
    gold = set(gold)
            
    #print(gold)

    return [gold, k]
    
#print(gold)

# %%
[g,l] = glist('52795.key')
[ext,k] = extList('52795_ranked_list.csv',14)
rec = 0
prec=0

for i in ext:
    if i in g:
        prec += 1

prec /= k
print(prec)

for i in g:
    if i in ext:
        rec += 1

rec /= l

print(rec)

# tp=0
# fp=0
# fn=0
# fp=0
# g = glist('52795.key')
# ext = extList('52795_ranked_list.csv',150)
# for i in g:
#     #print(i)
#     if i in ext:
#         print(i)
#         tp=tp+1;
# print(tp)
# Out:
# 0.42857142857142855
# 0.5454545454545454

# %%
a = extList('52795_ranked_list.csv')
# Out:
# {'requir', 'attribut', 'univers', 'set', 'setsize', 'intersect', 'size', 'frequenc', 'count', 'absolut', 'gener', 'data', 'assum', 'import', 'absolut-bound', 'method', 'distribut', 'complement', 'bound', 'inform', 'formula', 'correl', 'set-size', 'level', 'absolutbound', 'valu'}

# %%
len(glist('52795.key'))
# Out:
# {'databas-theori', 'rule-base-system-architectur', 'architectur', 'set-intersect', 'distribut-inform', 'base-system-architectur', 'rule-base', 'fileorganis', 'settheori', 'rule-base-system', 'boolean', 'system', 'rulebasesystem', 'set', 'statist', 'intersect', 'size', 'systemarchitectur', 'form', 'access', 'union', 'databas-access', 'basesystem', 'analysi', 'unionsize', 'rule', 'set-theori', 'close-form', 'closeformbound', 'closeform', 'organis', 'form-bound', 'system-architectur', 'base-system', 'databasaccess', 'distribut', 'booleanalgebra', 'bound', 'base', 'basesystemarchitectur', 'databastheori', 'rulebasesystemarchitectur', 'statistanalysi', 'close', 'distributinform', 'rulebase', 'algebra', 'formbound', 'databas', 'inform', 'setintersect', 'close-form-bound', 'union-size', 'statist-analysi', 'boolean-algebra', 'file', 'theori', 'file-organis'}
# 58

# %%
mx = 0
x=0
for k in range(1,1000):
    rec = 0
    #k = 8
    prec = 0
    for every_file in (os.listdir(gold_data)):
        #print(every_file)
        [g,l] = glist(every_file)
        [ext,k] = extList(every_file[:-4]+'_ranked_list.csv',k)
        #print(g,ext)
        r=0
        for i in g:
            if i in ext:
                #print(i)
                r += 1
        #print(r,l)
        r /= l
        rec += r

        p=0
        for i in ext:
            if i in g:
                #print(i)
                p += 1
        #print(r,l)
        p /= k
        prec += p

    rec /= 2304
    prec /= 2304

    f1 = 2*prec*rec
    f1 /= prec+rec
    
    if (f1>mx):
        mx = f1;
        x = k

    print(rec, prec, f1, mx, x)
# Out:
#
# 1.3635723154531325 0.18749999999999956 0.32966845787943816 0.4041707492545063 10
# 1.3834960833706633 0.18521255630630928 0.32669017019452673 0.4041707492545063 10
# 1.4062900080873275 0.18338815789473586 0.32446433443914846 0.4041707492545063 10
# 1.4395075799025996 0.18269230769230949 0.3242349647833903 0.4041707492545063 10
# 1.4627693304614386 0.18110894097222252 0.322311705106334 0.4041707492545063 10
# 1.4848631021686667 0.17934874661246686 0.320041389514314 0.4041707492545063 10
# 1.508131841396542 0.1779823908730146 0.3183899474262507 0.4041707492545063 10
# 1.5284067615857995 0.17624555878552794 0.3160467393005865 0.4041707492545063 10
# 1.5470973077725767 0.17445943813131237 0.3135600701988572 0.4041707492545063 10
# 1.5672042765394165 0.17278163580247002 0.31124863324054447 0.4041707492545063 10
# 1.5870220728526943 0.17131831219806765 0.30925291286459666 0.4041707492545063 10
# 1.6030464558082413 0.16949246453901 0.3065707516450307 0.4041707492545063 10
# 1.6210465371587583 0.1677969473379627 0.3041145441570504 0.4041707492545063 10
# 1.6381508565072564 0.16616177721088232 0.3017193944885898 0.4041707492545063 10
# 1.6564774708359615 0.16460069444444494 0.29944606138220736 0.4041707492545063 10
# 1.673702855480793 0.16311785130719103 0.29726452070561227 0.4041707492545063 10
# 1.68948531494195 0.16150006677350526 0.2948180940501084 0.4041707492545063 10
# 1.7085676421766594 0.16008254716981152 0.29273735847501225 0.4041707492545063 10
# 1.7238431684528752 0.15858088991769406 0.29044314697977547 0.4041707492545063 10
# 1.739239196175863 0.15704703282828167 0.28808135708659205 0.4041707492545063 10
# 1.759337458246207 0.15590122767857126 0.28642160547111395 0.4041707492545063 10
# 1.772501943918544 0.1544149000974654 0.28408149676278527 0.4041707492545063 10
# 1.7882478213240631 0.15311452346743387 0.28207687631143136 0.4041707492545063 10
# 1.8017406317201425 0.1517184557438792 0.2798700091031377 0.4041707492545063 10
# 1.8183689356081858 0.15055700231481517 0.278088851159475 0.4041707492545063 10
# 1.832433447497502 0.14925574908925335 0.2760283775412601 0.4041707492545063 10
# 1.850709761464746 0.14813648073476865 0.2743158779668713 0.4041707492545063 10
# 1.8656505059951332 0.14696318342151743 0.2724635522006017 0.4041707492545063 10
# 1.8797574223869447 0.1458401150173611 0.2706796721691823 0.4041707492545063 10
# 1.8933958999720748 0.14456463675213868 0.26861961806917223 0.4041707492545063 10
# 1.9069988322477076 0.14351851851851744 0.2669469215839242 0.4041707492545063 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-5f3d941c1b3b> in <module>
#       8         #print(every_file)
#       9         [g,l] = glist(every_file)
# ---> 10         [ext,k] = extList(every_file[:-4]+'_ranked_list.csv',k)
#      11         #print(g,ext)
#      12         r=0
#
# <ipython-input-41-64da936c9b6a> in extList(fil, k)
#       6     with open(phrase_data+'/'+fil, "r") as f:
#       7         reader = csv.reader(f)
# ----> 8         reader=list(reader)
#       9     #print(reader)
#      10     for i in range(1,len(reader)):
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     316         raise NotImplementedError
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
#
# KeyboardInterrupt:
