# %%
import csv
import networkx as nx

# %%
rdr = csv.reader(open('index.csv','r'))

# %%
rdr = list(rdr)

# %%
rdr = sorted(rdr,key=lambda l:l[2],reverse = True)

# %%
print(rdr)
# Out:
# []

# %%
for i in rdr:
    i[2] =float(i[2])

# %%
m = 0
d = 0

for i in rdr:
    if m < 10 and i[0] == 'model':
        print(i)
        m += 1
    if d<10 and i[0] == 'document':
        print(i)
        d += 1
# Out:
# ['model', 'gener', 52.79275052968743]
# ['model', 'time', 37.72278603088154]
# ['model', 'present', 33.79763014279452]
# ['model', 'show', 33.13669005812013]
# ['model', 'perform', 32.277703069771]
# ['model', 'data', 31.95356195545792]
# ['model', 'applic', 31.26082988728419]
# ['model', 'process', 31.016001750559322]
# ['model', 'techniqu', 24.6034020613246]
# ['model', 'inform', 23.39578043460142]
# ['document', 'describ', 4.112153086948819]
# ['document', 'similar', 4.095234104837495]
# ['document', 'word', 4.071258737611789]
# ['document', 'link', 3.96588219576624]
# ['document', 'categori', 3.5681845718066256]
# ['document', 'featur', 3.1710475673543446]
# ['document', 'current', 2.9791810086932036]
# ['document', 'html', 2.9657738095238098]
# ['document', 'collabor', 2.642857142857143]
# ['document', 'sourc', 2.641316526610644]

# %%
wrtr = csv.writer(open('knoGraph1.csv','w'))

# %%
wrtr.writerows(rdr)

# %%
G = nx.Graph()

# %%
print(rdr[0])
# Out:
# ['paper', 'properti', '24.35365728557157']

# %%
for i in rdr:
    for j in i[1:]:
        r = csv.reader(open(''))
    d[i[0]] = i[1:]

# %%
G.number_of_edges()
# Out:
# 1612400

# %%
d = dict()

# %%
rdr = csv.reader(open('index1.csv', 'r'))

# %%
wrtr = csv.writer(open('index1.csv','w'))

# %%
import os
import pandas as pd

# %%
rdr = csv.reader(open('index.csv','r'))

# %%
for i in rdr:
    docs = []
    for j in i[1:]:
        print(i[0])
        if j == '':
            break
        rnklst = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/'+j[:-4] + '_ranked_list.csv', 'r'))
        tup = [j]
        for k in range(50):
            if rnklst['Words'][k] == i[0]:
                tup.append(k)
                break
        docs.append(tup)
    lst = [i[0]] + docs
    wrtr.writerow(lst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-20793f44f02c> in <module>
#       5         if j == '':
#       6             break
# ----> 7         rnklst = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/'+j[:-4] + '_ranked_list.csv', 'r'))
#       8         tup = [j]
#       9         for k in range(50):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/_ranked_list.csv'

# %%
rnklst = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/'+j[:-4] + '_ranked_list.csv', 'r'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-8059a1c5f296> in <module>
# ----> 1 rnklst = pd.read_csv(open('/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/'+j[:-4] + '_ranked_list.csv', 'r'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nayan/coding/Major/sCake Phrase/venv/SCScore_W/_ranked_list.csv'

# %%
rnklst['Words'][0]
# Out:
# 'paper'

# %%
len(list(rdr))
# Out:
# 6138

# %%
rdr = list(rdr)

# %% [raw]
# print(rdr[0])

# %%
print(rdr[0])
# Out:
# ['paper', "['255000.csv', 0]", "['571159.csv', 18]", "['261851.csv', 32]", "['1029352.csv', 14]", "['286977.csv', 34]", "['305097.csv', 39]", "['298560.csv', 29]", "['264559.csv', 2]", "['586145.csv', 18]", "['262521.csv', 32]", "['587964.csv', 1]", "['626956.csv', 18]", "['316485.csv', 37]", "['1016179.csv', 16]", "['544923.csv', 1]", "['502544.csv', 1]", "['593313.csv', 44]", "['588626.csv', 43]", "['597100.csv', 41]", "['347551.csv', 13]", "['176718.csv', 25]", "['155220.csv', 25]", "['373294.csv', 37]", "['351545.csv', 1]", "['635238.csv', 20]", "['271804.csv', 16]", "['564412.csv', 33]", "['1035804.csv', 1]", "['330368.csv', 16]", "['587257.csv', 3]", "['586907.csv', 19]", "['505522.csv', 1]", "['587812.csv', 0]", "['603086.csv', 29]", "['364001.csv', 23]", "['607624.csv', 22]", "['591512.csv', 7]", "['289843.csv', 11]", "['284973.csv', 11]", "['500505.csv', 10]", "['308845.csv', 24]", "['224498.csv', 18]", "['629048.csv', 32]", "['587740.csv', 5]", "['587787.csv', 2]", "['241662.csv', 17]", "['290124.csv', 37]", "['296379.csv', 24]", "['604189.csv', 48]", "['599486.csv', 28]", "['1010995.csv', 4]", "['1008415.csv', 34]", "['595043.csv', 6]", "['352664.csv', 28]", "['192334.csv', 34]", "['224525.csv', 1]", "['586129.csv', 45]", "['599674.csv', 18]", "['195891.csv', 25]", "['587883.csv', 37]", "['272132.csv', 34]", "['1024923.csv', 23]", "['297106.csv', 45]", "['598174.csv', 3]", "['254287.csv', 30]", "['1011932.csv', 15]", "['545249.csv', 32]", "['151529.csv', 13]", "['245610.csv', 1]", "['586956.csv', 30]", "['330384.csv', 33]", "['1022634.csv', 48]", "['569859.csv', 35]", "['585500.csv', 1]", "['351138.csv', 17]", "['300125.csv', 0]", "['593316.csv', 2]", "['331273.csv', 0]", "['1036463.csv', 30]", "['626961.csv', 19]", "['614306.csv', 0]", "['1040306.csv', 6]", "['614347.csv', 2]", "['591458.csv', 8]", "['504535.csv', 15]", "['263443.csv', 33]", "['206000.csv', 2]", "['383198.csv', 23]", "['258231.csv', 19]", "['629452.csv', 41]", "['544819.csv', 19]", "['568342.csv', 48]", "['225071.csv', 32]", "['601779.csv', 32]", "['257725.csv', 26]", "['244582.csv', 8]", "['1037287.csv', 16]", "['564104.csv', 30]", "['177759.csv', 26]", "['588569.csv', 2]", "['594258.csv', 11]", "['1024022.csv', 1]", "['608786.csv', 31]", "['599662.csv', 19]", "['282725.csv', 35]", "['589256.csv', 10]", "['312215.csv', 2]", "['343587.csv', 30]", "['142824.csv', 27]", "['596250.csv', 34]", "['594334.csv', 6]", "['224494.csv', 25]", "['349155.csv', 18]", "['587742.csv', 3]", "['206026.csv', 18]", "['285191.csv', 48]", "['310690.csv', 9]", "['270948.csv', 12]", "['586901.csv', 4]", "['614361.csv', 48]", "['628030.csv', 12]", "['264266.csv', 38]", "['629361.csv', 12]", "['504566.csv', 0]", "['263449.csv', 12]", "['597056.csv', 15]", "['369220.csv', 24]", "['594830.csv', 21]", "['300255.csv', 12]", "['593311.csv', 24]", "['1035549.csv', 32]", "['345772.csv', 23]", "['609461.csv', 29]", "['604198.csv', 29]", "['587001.csv', 49]", "['273702.csv', 29]", "['354878.csv', 15]", "['261998.csv', 1]", "['292377.csv', 6]", "['591464.csv', 15]", "['567199.csv', 44]", "['598422.csv', 1]", "['589159.csv', 1]", "['312552.csv', 22]", "['205848.csv', 23]", "['510800.csv', 49]", "['590817.csv', 15]", "['587583.csv', 2]", "['581499.csv', 35]", "['629444.csv', 4]", "['581774.csv', 14]", "['300896.csv', 15]", "['592983.csv', 17]", "['325396.csv', 48]", "['358684.csv', 36]", "['337358.csv', 13]", "['628731.csv', 1]", "['255883.csv', 12]", "['586857.csv', 35]", "['587814.csv', 1]", "['608747.csv', 19]", "['588515.csv', 27]", "['181336.csv', 10]", "['276487.csv', 25]", "['319435.csv', 18]", "['325700.csv', 25]", "['589234.csv', 5]", "['378636.csv', 15]", "['192795.csv', 24]", "['502111.csv', 21]", "['251709.csv', 17]", "['290287.csv', 34]", "['589182.csv', 3]", "['606895.csv', 15]", "['587528.csv', 1]", "['502567.csv', 9]", "['152393.csv', 42]", "['306259.csv', 15]", "['591532.csv', 28]", "['307967.csv', 11]", "['599694.csv', 23]", "['587829.csv', 13]", "['305664.csv', 42]", ...

# %%
s = rdr[0][1]

# %%
lst = literal_eval(s)

# %%
from ast import literal_eval

# %%
print(lst[0])
# Out:
# 255000.csv

# %%
for i in rdr:
    d[i[0]] = i[1:]

# %%
for i in range(len(d['paper'])):
    d['paper'][i] = literal_eval(d['paper'][i])
d['paper'].sort(key = lambda x: x[1])
print(d['paper'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-cc2b7887ab5f> in <module>
#       1 for i in range(len(d['paper'])):
# ----> 2     d['paper'][i] = literal_eval(d['paper'][i])
#       3 d['paper'].sort(key = lambda x: x[1])
#       4 print(d['paper'])
#
# /usr/lib/python3.6/ast.py in literal_eval(node_or_string)
#      83                     return left - right
#      84         raise ValueError('malformed node or string: ' + repr(node))
# ---> 85     return _convert(node_or_string)
#      86
#      87
#
# /usr/lib/python3.6/ast.py in _convert(node)
#      82                 else:
#      83                     return left - right
# ---> 84         raise ValueError('malformed node or string: ' + repr(node))
#      85     return _convert(node_or_string)
#      86
#
# ValueError: malformed node or string: ['255000.csv', 0]

# %%
d['paper'].sort(key = lambda x: x[1])
print(d['paper'])
# Out:
# [['255000.csv', 0], ['587812.csv', 0], ['300125.csv', 0], ['331273.csv', 0], ['614306.csv', 0], ['504566.csv', 0], ['587964.csv', 1], ['544923.csv', 1], ['502544.csv', 1], ['351545.csv', 1], ['1035804.csv', 1], ['505522.csv', 1], ['224525.csv', 1], ['245610.csv', 1], ['585500.csv', 1], ['1024022.csv', 1], ['261998.csv', 1], ['598422.csv', 1], ['589159.csv', 1], ['628731.csv', 1], ['587814.csv', 1], ['587528.csv', 1], ['590960.csv', 1], ['264559.csv', 2], ['587787.csv', 2], ['593316.csv', 2], ['614347.csv', 2], ['206000.csv', 2], ['588569.csv', 2], ['312215.csv', 2], ['587583.csv', 2], ['587257.csv', 3], ['598174.csv', 3], ['587742.csv', 3], ['589182.csv', 3], ['1010995.csv', 4], ['586901.csv', 4], ['629444.csv', 4], ['587740.csv', 5], ['589234.csv', 5], ['595043.csv', 6], ['1040306.csv', 6], ['594334.csv',